# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron

# %%
df=pd.read_csv('iq_cgpa_dataset.csv')

# %%
df.head()
# Out:
#     iq  cgpa  placement
# 0   95   2.1          0
# 1  102   2.5          0
# 2  110   2.8          0
# 3  115   3.0          0
# 4  120   3.2          1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=df['iq'], y=df['cgpa'], hue=df['placement'])
plt.show()

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
p=Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 7. , 48.9]])

# %%
p.intercept_
# Out:
# array([-51.])
